# %%
import pandas as pd
file_path = './data/dataset_12__gen_col_3.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0   hadm_id               intime              outtime   stay_id  \
# 0           0  20000147  2121-08-30 16:33:54  2121-08-31 21:29:49  30503572
# 1           1  20005241  2178-01-26 11:10:05  2178-01-27 17:41:19  30969401
# 2           2  20006154  2139-03-17 23:00:00  2139-03-21 16:31:49  30306704
# 3           3  20012316  2137-08-11 19:50:39  2137-08-16 17:37:45  32375282
# 4           4  20014283  2158-02-13 04:59:54  2158-02-15 18:54:41  37734890
#
#    subject_id                                first_careunit  is_aki  \
# 0    14990224                      Coronary Care Unit (CCU)    True
# 1    17038060  Cardiac Vascular Intensive Care Unit (CVICU)    True
# 2    17368229                           Trauma SICU (TSICU)    True
# 3    18755721                      Coronary Care Unit (CCU)    True
# 4    19836972                      Coronary Care Unit (CCU)    True
#
#               aki_time  is_hf  ...  max_troponin_t  mean_troponin_t  \
# ...
